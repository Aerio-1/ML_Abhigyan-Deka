# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('insurance.csv')

# %%
df.head()
# Out:
#    age  insurance
# 0   19        220
# 1   45        980
# 2   34        520
# 3   28        410
# 4   52       1500

# %%
plt.scatter(df['insurance'],df['age'])
plt.xlabel('AGE')
plt.ylabel('Insurance (in Thousands)')
# Out:
# Text(0, 0.5, 'Insurance (in Thousands)')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
X
# Out:
#      age
# 0     19
# 1     45
# 2     34
# 3     28
# 4     52
# ..   ...
# 141   54
# 142   37
# 143   48
# 144   29
# 145   60
#
# [146 rows x 1 columns]

# %%
y
# Out:
# 0       220
# 1       980
# 2       520
# 3       410
# 4      1500
#        ...
# 141    1590
# 142     700
# 143    1180
# 144     405
# 145    2150
# Name: insurance, Length: 146, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_test
# Out:
#      age
# 91    26
# 126   26
# 3     28
# 35    38
# 123   57
# 82    43
# 128   43
# 12    55
# 42    51
# 125   46
# 5     23
# 53    52
# 93    41
# 121   49
# 48    29
# 59    58
# 24    24
# 86    49
# 41    20
# 77    34
# 85    31
# 122   21
# 25    53
# 2     34
# 113   53
# 64    33
# 144   29
# 23    50
# 44    28
# 54    39

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      age
# 91    26
# 126   26
# 3     28
# 35    38
# 123   57
# 82    43
# 128   43
# 12    55
# 42    51
# 125   46
# 5     23
# 53    52
# 93    41
# 121   49
# 48    29
# 59    58
# 24    24
# 86    49
# 41    20
# 77    34
# 85    31
# 122   21
# 25    53
# 2     34
# 113   53
# 64    33
# 144   29
# 23    50
# 44    28
# 54    39

# %%
y_test
# Out:
# 91      320
# 126     315
# 3       410
# 35      760
# 123    1920
# 82      940
# 128     930
# 12     1700
# 42     1480
# 125    1040
# 5       260
# 53     1550
# 93      900
# 121    1280
# 48      400
# 59     1950
# 24      270
# 86     1320
# 41      210
# 77      560
# 85      470
# 122     195
# 25     1650
# 2       520
# 113    1620
# 64      540
# 144     405
# 23     1450
# 44      330
# 54      830
# Name: insurance, dtype: int64

# %%
lr.predict(X_test.iloc[[0]])
# lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# array([228.77996263])

# %%
plt.scatter(df['age'],df['insurance'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('Age')
plt.ylabel('Insurance (in Thousands)')
# Out:
# Text(0, 0.5, 'Insurance (in Thousands)')

# %%
m = lr.coef_
m
# Out:
# array([52.61516492])

# %%
b = lr.intercept_
b
# Out:
# np.float64(-1139.2143253669215)

# %%
# y = mx + b

m * 500 + b
# Out:
# array([25168.36813609])

# %%
m * 2500 + b
# Out:
# array([130398.6979819])

# %%
m * 100 + b
# Out:
# array([4122.30216692])
